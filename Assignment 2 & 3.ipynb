# %%
# !pip install pandas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(pd.__version__)
# Out:
# 1.3.4

# %% [markdown]
#  ##Uncover the factors that lead to employee attrition and explore important questions such as:
# 1. Show a breakdown of distance from home by job role and attrition

# %%
attrition = pd.read_csv('HR_Employee_Attrition.csv')

# %%
attrition
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df = attrition

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df = pd.read_csv('HR_Employee_Attrition.csv')
HR_Analysis = pd.read_csv('HR_Employee_Attrition.csv')
HR_Analysis.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
Distance_by_JR_Attrition=HR_Analysis[['DistanceFromHome','JobRole', 'Attrition']]
Distance_by_JR_Attrition.head()
# Out:
#    DistanceFromHome                JobRole Attrition
# 0                 1        Sales Executive       Yes
# 1                 8     Research Scientist        No
# 2                 2  Laboratory Technician       Yes
# 3                 3     Research Scientist        No
# 4                 2  Laboratory Technician        No

# %%
Distance_by_JR_Attrition.groupby(['JobRole', 'Attrition'])['DistanceFromHome'].sum()
# Out:
# JobRole                    Attrition
# Healthcare Representative  No           1123
#                            Yes           159
# Human Resources            No            264
#                            Yes           161
# Laboratory Technician      No           1838
#                            Yes           599
# Manager                    No            769
#                            Yes            50
# Manufacturing Director     No           1287
#                            Yes            88
# Research Director          No            661
#                            Yes            14
# Research Scientist         No           2173
#                            Yes           459
# Sales Executive            No           2428
#                            Yes           721
# Sales Representative       No            450
#                            Yes           269
# Name: DistanceFromHome, dtype: int64

# %% [markdown]
# #Compare average monthly income by education and attrition

# %%
Income_by_Education_Attrition=HR_Analysis[['MonthlyIncome','Education', 'Attrition']]
Income_by_Education_Attrition.head()
# Out:
#    MonthlyIncome  Education Attrition
# 0           5993          2       Yes
# 1           5130          1        No
# 2           2090          2       Yes
# 3           2909          4        No
# 4           3468          1        No

# %%
Income_by_Education_Attrition.groupby(['Education', 'Attrition'])['MonthlyIncome'].mean()
# Out:
# Education  Attrition
# 1          No           5926.129496
#            Yes          4360.161290
# 2          No           6586.058824
#            Yes          4282.545455
# 3          No           6882.919662
#            Yes          4770.242424
# 4          No           7087.814706
#            Yes          5335.155172
# 5          No           8559.906977
#            Yes          5850.200000
# Name: MonthlyIncome, dtype: float64

# %% [markdown]
# #Express results using visualization tools

# %%
df = sns.load_dataset('HR_Employee_Attrition.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4068/841778382.py in <module>
# ----> 1 df = sns.load_dataset('HR_Employee_Attrition.csv')
#       2 df.head()
#
# ~\anaconda3\lib\site-packages\seaborn\utils.py in load_dataset(name, cache, data_home, **kws)
#     593         if not os.path.exists(cache_path):
#     594             if name not in get_dataset_names():
# --> 595                 raise ValueError(f"'{name}' is not one of the example datasets.")
#     596             urlretrieve(url, cache_path)
#     597         full_path = cache_path
#
# ValueError: 'HR_Employee_Attrition.csv' is not one of the example datasets.
